# %% [markdown]
# # Skin cancer

# %% [markdown]
# ## SkinVision | Skin Cancer Melanoma Detection App | Check Your Skin

# %% [markdown]
# https://www.skinvision.com

# %% [markdown]
# ## How Machine Learning Technology Detects Skin Cancer > SkinVision

# %% [markdown]
# https://www.skinvision.com/articles/how-machine-learning-detects-skin-cancer

# %%
# %%HTML
# <video width="1000" height="700" controls>
#   <source src="skinVision.mp4" type="video/mp4">
# </video>
# Out:
# <video width="1000" height="700" controls>
#   <source src="skinVision.mp4" type="video/mp4">
# </video>
# https://www.youtube.com/watch?v=TWH_wfN7N7g

# %% [markdown]
# https://www.theguardian.com/society/2018/may/29/skin-cancer-computer-learns-to-detect-skin-cancer-more-accurately-than-a-doctor

# %%
from IPython.display import Image
Image("1.jpg", width="700")

# %% [markdown]
# https://med.stanford.edu/news/all-news/2017/02/algorithm-matches-dermatologists-ability-to-identify-skin-cancer.html

# %%
Image("2.jpg", width="700")

# %% [markdown]
# ## The International Skin Imaging Collaboration
# https://www.isic-archive.com/#!/topWithHeader/wideContentTop/main

# %% [markdown]
# ## Melanoma-Cancer-Detection-V1

# %% [markdown]
# https://github.com/vgupta-ai/Melanoma-Cancer-Detection-V1

# %% [markdown]
# ## ISIC Melanoma Project Dataset Downloader
#
# https://github.com/vgupta-ai/ISIC-Dataset-Downloader
